# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd /content/drive/My Drive/Backup/EIP/Assignment_5
# Out:
# /content/drive/My Drive/Backup/EIP/Assignment_5

# %%
# %ls
# Out:
# hvc_annotations.csv  model.png  saved_models/
# hvc_data.zip         resized/   saved_models_val/

# %%
# %tensorflow_version 1.x

import cv2
import json

import numpy as np
import pandas as pd

from functools import partial
from pathlib import Path 
from tqdm import tqdm

from google.colab.patches import cv2_imshow

import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, OneHotEncoder


from keras.applications import VGG16, InceptionResNetV2
from keras.layers.core import Dropout
from keras.layers.core import Flatten
from keras.layers.core import Dense
from keras.layers import Input
from keras.models import Model
from keras.optimizers import SGD
from keras.preprocessing.image import ImageDataGenerator
# Out:
# Using TensorFlow backend.

# %%
# load annotations
df = pd.read_csv("hvc_annotations.csv")
del df["filename"] # remove unwanted column
df.head()
# Out:
#    gender imagequality    age  ...        emotion        bodypose     image_path
# 0    male      Average  35-45  ...        Neutral  Front-Frontish  resized/1.jpg
# 1  female      Average  35-45  ...  Angry/Serious  Front-Frontish  resized/2.jpg
# 2    male         Good  45-55  ...        Neutral  Front-Frontish  resized/3.jpg
# 3    male         Good  45-55  ...        Neutral  Front-Frontish  resized/4.jpg
# 4  female         Good  35-45  ...        Neutral  Front-Frontish  resized/5.jpg
#
# [5 rows x 9 columns]

# %%
# one hot encoding of labels

one_hot_df = pd.concat([
    df[["image_path"]],
    pd.get_dummies(df.gender, prefix="gender"),
    pd.get_dummies(df.imagequality, prefix="imagequality"),
    pd.get_dummies(df.age, prefix="age"),
    pd.get_dummies(df.weight, prefix="weight"),
    pd.get_dummies(df.carryingbag, prefix="carryingbag"),
    pd.get_dummies(df.footwear, prefix="footwear"),
    pd.get_dummies(df.emotion, prefix="emotion"),
    pd.get_dummies(df.bodypose, prefix="bodypose"),
], axis = 1)

one_hot_df.head().T
# Out:
#                                                   0  ...              4
# image_path                            resized/1.jpg  ...  resized/5.jpg
# gender_female                                     0  ...              1
# gender_male                                       1  ...              0
# imagequality_Average                              1  ...              0
# imagequality_Bad                                  0  ...              0
# imagequality_Good                                 0  ...              1
# age_15-25                                         0  ...              0
# age_25-35                                         0  ...              0
# age_35-45                                         1  ...              1
# age_45-55                                         0  ...              0
# age_55+                                           0  ...              0
# weight_normal-healthy                             1  ...              0
# weight_over-weight                                0  ...              0
# weight_slightly-overweight                        0  ...              1
# weight_underweight                                0  ...              0
# carryingbag_Daily/Office/Work Bag                 0  ...              0
# carryingbag_Grocery/Home/Plastic Bag              1  ...              0
# carryingbag_None                                  0  ...              1
# footwear_CantSee                                  0  ...              1
# footwear_Fancy                                    0  ...              0
# footwear_Normal                                   1  ...              0
# emotion_Angry/Serious                             0  ...              0
# emotion_Happy                                     0  ...              0
# emotion_Neutral                                   1  ...              1
# emotion_Sad                                       0  ...              0
# bodypose_Back                                     0  ...              0
# bodypose_Front-Frontish                           1  ...              1
# bodypose_Side                                     0  ...              0
#
# [28 rows x 5 columns]

# %%
from keras.preprocessing.image import ImageDataGenerator

def get_random_eraser(p=0.5, s_l=0.02, s_h=0.4, r_1=0.3, r_2=1/0.3, v_l=0, v_h=255, pixel_level=False):
    def eraser(input_img):
        img_h, img_w, img_c = input_img.shape
        p_1 = np.random.rand()

        if p_1 > p:
            return input_img

        while True:
            s = np.random.uniform(s_l, s_h) * img_h * img_w
            r = np.random.uniform(r_1, r_2)
            w = int(np.sqrt(s / r))
            h = int(np.sqrt(s * r))
            left = np.random.randint(0, img_w)
            top = np.random.randint(0, img_h)

            if left + w <= img_w and top + h <= img_h:
                break

        if pixel_level:
            c = np.random.uniform(v_l, v_h, (h, w, img_c))
        else:
            c = np.random.uniform(v_l, v_h)

        input_img[top:top + h, left:left + w, :] = c

        return input_img

    return eraser

# %%
import keras
import numpy as np

# Label columns per attribute
_gender_cols_ = [col for col in one_hot_df.columns if col.startswith("gender")]
_imagequality_cols_ = [col for col in one_hot_df.columns if col.startswith("imagequality")]
_age_cols_ = [col for col in one_hot_df.columns if col.startswith("age")]
_weight_cols_ = [col for col in one_hot_df.columns if col.startswith("weight")]
_carryingbag_cols_ = [col for col in one_hot_df.columns if col.startswith("carryingbag")]
_footwear_cols_ = [col for col in one_hot_df.columns if col.startswith("footwear")]
_emotion_cols_ = [col for col in one_hot_df.columns if col.startswith("emotion")]
_bodypose_cols_ = [col for col in one_hot_df.columns if col.startswith("bodypose")]

class PersonDataGenerator(keras.utils.Sequence):
    """Ground truth data generator"""

    
    def __init__(self, df, batch_size=32, shuffle=True, augmentation=None):
        self.df = df
        self.batch_size=batch_size
        self.shuffle = shuffle
        self.on_epoch_end()
        self.augmentation=augmentation

    def __len__(self):
        return int(np.floor(self.df.shape[0] / self.batch_size))

    def __getitem__(self, index):
        """fetch batched images and targets"""
        batch_slice = slice(index * self.batch_size, (index + 1) * self.batch_size)
        items = self.df.iloc[batch_slice]
        image = np.stack([cv2.imread(item["image_path"]) for _, item in items.iterrows()])
        
        if self.augmentation is not None:
          image = self.augmentation.flow(image, shuffle=False).next()        
        
        target = {
            "gender_output": items[_gender_cols_].values,
            "image_quality_output": items[_imagequality_cols_].values,
            "age_output": items[_age_cols_].values,
            "weight_output": items[_weight_cols_].values,
            "bag_output": items[_carryingbag_cols_].values,
            "pose_output": items[_bodypose_cols_].values,
            "footwear_output": items[_footwear_cols_].values,
            "emotion_output": items[_emotion_cols_].values,
        }
        return image, target

    def on_epoch_end(self):
        """Updates indexes after each epoch"""
        if self.shuffle == True:
            self.df = self.df.sample(frac=1).reset_index(drop=True)

# %%
from sklearn.model_selection import train_test_split
train_df, val_df = train_test_split(one_hot_df, test_size=0.15)
train_df.shape, val_df.shape
# Out:
# ((11537, 28), (2036, 28))

# %%
train_df.head()
# Out:
#             image_path  gender_female  ...  bodypose_Front-Frontish  bodypose_Side
# 2187  resized/2188.jpg              0  ...                        1              0
# 1084  resized/1085.jpg              1  ...                        1              0
# 3511  resized/3512.jpg              1  ...                        1              0
# 3919  resized/3920.jpg              0  ...                        1              0
# 6025  resized/6026.jpg              0  ...                        0              0
#
# [5 rows x 28 columns]

# %%
# create train and validation data generators
train_gen = PersonDataGenerator(train_df, batch_size=32, 
                                augmentation=ImageDataGenerator(
                                    horizontal_flip=True, 
                                    preprocessing_function=get_random_eraser(v_l=0, v_h=1, pixel_level=False),                                    
                                    ))


valid_gen = PersonDataGenerator(val_df, batch_size=64, shuffle=False)

# %%
# get number of output units from data
images, targets = next(iter(train_gen))
num_units = { k.split("_output")[0]:v.shape[1] for k, v in targets.items()}
num_units
# Out:
# {'age': 5,
#  'bag': 3,
#  'emotion': 4,
#  'footwear': 3,
#  'gender': 2,
#  'image_quality': 3,
#  'pose': 3,
#  'weight': 4}

# %%
backbone = InceptionResNetV2(
    weights=None, 
    include_top=False, 
    input_tensor=Input(shape=(224, 224, 3))
)


neck = backbone.output
neck = Flatten(name="flatten")(neck)
neck = Dense(512, activation="relu")(neck)


def build_tower(in_layer):
    neck = Dropout(0.1)(in_layer)
    neck = Dense(256, activation="relu")(neck)
    neck = Dropout(0.15)(neck)
    neck = Dense(256, activation="relu")(neck)
    return neck


def build_head(name, in_layer):
    return Dense(
        num_units[name], activation="softmax", name=f"{name}_output"
    )(in_layer)

# heads
gender = build_head("gender", build_tower(neck))
image_quality = build_head("image_quality", build_tower(neck))
age = build_head("age", build_tower(neck))
weight = build_head("weight", build_tower(neck))
bag = build_head("bag", build_tower(neck))
footwear = build_head("footwear", build_tower(neck))
emotion = build_head("emotion", build_tower(neck))
pose = build_head("pose", build_tower(neck))


model = Model(
    inputs=backbone.input, 
    outputs=[gender, image_quality, age, weight, bag, footwear, pose, emotion]
)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:203: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2041: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4271: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
# model.summary()

# %%
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras.callbacks import ReduceLROnPlateau

# %%
def lr_schedule(epoch):
    """Learning Rate Schedule

    Learning rate is scheduled to be reduced after 80, 120, 160, 180 epochs.
    Called automatically every epoch as part of callbacks during training.

    # Arguments
        epoch (int): The number of epochs

    # Returns
        lr (float32): learning rate
    """
    lr = 1e-3
    if epoch > 45:
        lr *= 0.5e-3
    elif epoch > 35:
        lr *= 1e-3
    elif epoch > 25:
        lr *= 1e-2
    elif epoch > 15:
        lr *= 1e-1
    print('Learning rate: ', lr)
    return lr

# %%
losses = {
	"gender_output": "binary_crossentropy",
	"image_quality_output": "categorical_crossentropy",
	"age_output": "categorical_crossentropy",
	"weight_output": "categorical_crossentropy",

}
loss_weights = {"gender_output": 1.0, "image_quality_output": 1.0, "age_output": 1.0}
opt = SGD(lr=0.001, momentum=0.9)
model.compile(
    optimizer=opt,
    loss="categorical_crossentropy", 
    loss_weights=loss_weights, 
    metrics=["accuracy"]
)

lr_scheduler = LearningRateScheduler(lr_schedule, verbose=1)

lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6)

callbacks = [ lr_reducer, lr_scheduler]
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3576: The name tf.log is deprecated. Please use tf.math.log instead.

# %%
history=model.fit_generator(
    generator=train_gen,
    validation_data=valid_gen,
    use_multiprocessing=True,
    workers=8,
    epochs=100,
    verbose=1,
    callbacks=callbacks
)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Epoch 1/100
# Learning rate:  0.001
#
# Epoch 00001: LearningRateScheduler setting learning rate to 0.001.
# 359/360 [============================>.] - ETA: 1s - loss: 7.9908 - gender_output_loss: 0.6944 - image_quality_output_loss: 0.9990 - age_output_loss: 1.4572 - weight_output_loss: 1.0216 - bag_output_loss: 0.9343 - footwear_output_loss: 0.9923 - pose_output_loss: 0.9494 - emotion_output_loss: 0.9427 - gender_output_acc: 0.5553 - image_quality_output_acc: 0.5440 - age_output_acc: 0.3841 - weight_output_acc: 0.6260 - bag_output_acc: 0.5532 - footwear_output_acc: 0.5232 - pose_output_acc: 0.6078 - emotion_output_acc: 0.7091
# 360/360 [==============================] - 500s 1s/step - loss: 7.9896 - gender_output_loss: 0.6942 - image_quality_output_loss: 0.9990 - age_output_loss: 1.4569 - weight_output_loss: 1.0216 - bag_output_loss: 0.9341 - footwear_output_loss: 0.9921 - pose_output_loss: 0.9489 - emotion_output_loss: 0.9428 - gender_output_acc: 0.5554 - image_quality_output_acc: 0.5437 - age_output_acc: 0.3845 - weight_output_acc: 0.6260 - bag_output_acc: 0.5533 - footwear_output_acc: 0.5235 - pose_output_acc: 0.6082 - emotion_output_acc: 0.7090 - val_loss: 7.8294 - val_gender_output_loss: 0.6630 - val_image_quality_output_loss: 1.0110 - val_age_output_loss: 1.4237 - val_weight_output_loss: 0.9817 - val_bag_output_loss: 0.9538 - val_footwear_output_loss: 0.9467 - val_pose_output_loss: 0.9223 - val_emotion_output_loss: 0.9272 - val_gender_output_acc: 0.5751 - val_image_quality_output_acc: 0.5323 - val_age_output_acc: 0.3926 - val_weight_output_acc: 0.6396 - val_bag_output_acc: 0.5459 - val_footwear_output_acc: 0.5559 - val_pose_output_acc: 0.6245 - val_emotion_output_acc: 0.7072
# Epoch 2/100
# Learning rate:  0.001
#
# Epoch 00002: LearningRateScheduler setting learning rate to 0.001.
# 359/360 [============================>.] - ETA: 0s - loss: 7.7663 - gender_output_loss: 0.6555 - image_quality_output_loss: 0.9822 - age_output_loss: 1.4305 - weight_output_loss: 0.9965 - bag_output_loss: 0.9143 - footwear_output_loss: 0.9381 - pose_output_loss: 0.9297 - emotion_output_loss: 0.9196 - gender_output_acc: 0.5918 - image_quality_output_acc: 0.5536 - age_output_acc: 0.3935 - weight_output_acc: 0.6354 - bag_output_acc: 0.5627 - footwear_output_acc: 0.5649 - pose_output_acc: 0.6165 - emotion_output_acc: 0.7120Learning rate:  0.001
# Epoch 5/100
# Learning rate:  0.001
#
# Epoch 00005: LearningRateScheduler setting learning rate to 0.001.
# 360/360 [==============================] - 169s 469ms/step - loss: 7.4441 - gender_output_loss: 0.5598 - image_quality_output_loss: 0.9598 - age_output_loss: 1.4066 - weight_output_loss: 0.9819 - bag_output_loss: 0.8892 - footwear_output_loss: 0.8825 - pose_output_loss: 0.8569 - emotion_output_loss: 0.9075 - gender_output_acc: 0.7040 - image_quality_output_acc: 0.5564 - age_output_acc: 0.3966 - weight_output_acc: 0.6347 - bag_output_acc: 0.5832 - footwear_output_acc: 0.5939 - pose_output_acc: 0.6248 - emotion_output_acc: 0.7122 - val_loss: 7.4552 - val_gender_output_loss: 0.5914 - val_image_quality_output_loss: 0.9640 - val_age_output_loss: 1.4007 - val_weight_output_loss: 0.9615 - val_bag_output_loss: 0.9063 - val_footwear_output_loss: 0.8866 - val_pose_output_loss: 0.8334 - val_emotion_output_loss: 0.9114 - val_gender_output_acc: 0.6840 - val_image_quality_output_acc: 0.5388 - val_age_output_acc: 0.3931 - val_weight_output_acc: 0.6396 - val_bag_output_acc: 0.5665 - val_footwear_output_acc: 0.5867 - val_pose_output_acc: 0.6351 - val_emotion_output_acc: 0.7072
# Epoch 6/100
# Learning rate:  0.001
#
# Epoch 00006: LearningRateScheduler setting learning rate to 0.001.
# 360/360 [==============================] - 168s 467ms/step - loss: 7.3086 - gender_output_loss: 0.5383 - image_quality_output_loss: 0.9528 - age_output_loss: 1.3981 - weight_output_loss: 0.9753 - bag_output_loss: 0.8782 - footwear_output_loss: 0.8719 - pose_output_loss: 0.7949 - emotion_output_loss: 0.8991 - gender_output_acc: 0.7232 - image_quality_output_acc: 0.5569 - age_output_acc: 0.3942 - weight_output_acc: 0.6345 - bag_output_acc: 0.5863 - footwear_output_acc: 0.5968 - pose_output_acc: 0.6463 - emotion_output_acc: 0.7119 - val_loss: 7.3659 - val_gender_output_loss: 0.6177 - val_image_quality_output_loss: 0.9892 - val_age_output_loss: 1.3880 - val_weight_output_loss: 0.9526 - val_bag_output_loss: 0.8909 - val_footwear_output_loss: 0.8670 - val_pose_output_loss: 0.7462 - val_emotion_output_loss: 0.9143 - val_gender_output_acc: 0.6719 - val_image_quality_output_acc: 0.5383 - val_age_output_acc: 0.3992 - val_weight_output_acc: 0.6396 - val_bag_output_acc: 0.5776 - val_footwear_output_acc: 0.6053 - val_pose_output_acc: 0.6981 - val_emotion_output_acc: 0.7072
# Epoch 7/100
# Learning rate:  0.001
#
# Epoch 00007: LearningRateScheduler setting learning rate to 0.001.
# 360/360 [==============================] - 169s 470ms/step - loss: 5.5771 - gender_output_loss: 0.2027 - image_quality_output_loss: 0.7785 - age_output_loss: 1.2593 - weight_output_loss: 0.8813 - bag_output_loss: 0.7189 - footwear_output_loss: 0.6262 - pose_output_loss: 0.3004 - emotion_output_loss: 0.8097 - gender_output_acc: 0.9169 - image_quality_output_acc: 0.6422 - age_output_acc: 0.4451 - weight_output_acc: 0.6520 - bag_output_acc: 0.6918 - footwear_output_acc: 0.7234 - pose_output_acc: 0.8817 - emotion_output_acc: 0.7123 - val_loss: 6.7943 - val_gender_output_loss: 0.4378 - val_image_quality_output_loss: 0.9315 - val_age_output_loss: 1.3413 - val_weight_output_loss: 0.9209 - val_bag_output_loss: 0.8527 - val_footwear_output_loss: 0.8299 - val_pose_output_loss: 0.5962 - val_emotion_output_loss: 0.8841 - val_gender_output_acc: 0.8266 - val_image_quality_output_acc: 0.5444 - val_age_output_acc: 0.4103 - val_weight_output_acc: 0.6457 - val_bag_output_acc: 0.6220 - val_footwear_output_acc: 0.6280 - val_pose_output_acc: 0.7807 - val_emotion_output_acc: 0.7056
# Epoch 27/100
# Learning rate:  1e-05
#
# Epoch 00027: LearningRateScheduler setting learning rate to 1e-05.
# 360/360 [==============================] - 168s 467ms/step - loss: 5.4784 - gender_output_loss: 0.1868 - image_quality_output_loss: 0.7660 - age_output_loss: 1.2410 - weight_output_loss: 0.8731 - bag_output_loss: 0.7112 - footwear_output_loss: 0.6129 - pose_output_loss: 0.2834 - emotion_output_loss: 0.8040 - gender_output_acc: 0.9252 - image_quality_output_acc: 0.6430 - age_output_acc: 0.4488 - weight_output_acc: 0.6505 - bag_output_acc: 0.6970 - footwear_output_acc: 0.7278 - pose_output_acc: 0.8870 - emotion_output_acc: 0.7129 - val_loss: 6.8164 - val_gender_output_loss: 0.4382 - val_image_quality_output_loss: 0.9348 - val_age_output_loss: 1.3403 - val_weight_output_loss: 0.9225 - val_bag_output_loss: 0.8464 - val_footwear_output_loss: 0.8443 - val_pose_output_loss: 0.6032 - val_emotion_output_loss: 0.8866 - val_gender_output_acc: 0.8342 - val_image_quality_output_acc: 0.5479 - val_age_output_acc: 0.4062 - val_weight_output_acc: 0.6421 - val_bag_output_acc: 0.6295 - val_footwear_output_acc: 0.6305 - val_pose_output_acc: 0.7818 - val_emotion_output_acc: 0.7041
# Epoch 28/100
# Learning rate:  1e-05
#
# Epoch 00028: LearningRateScheduler setting learning rate to 1e-05.
# Epoch 33/100
# Learning rate:  1e-05
#
# Epoch 00033: LearningRateScheduler setting learning rate to 1e-05.
# ...
# Learning rate:  5e-07
#
# Epoch 00053: LearningRateScheduler setting learning rate to 5e-07.
# 359/360 [============================>.] - ETA: 0s - loss: 5.4233 - gender_output_loss: 0.1872 - image_quality_output_loss: 0.7524 - age_output_loss: 1.2295 - weight_output_loss: 0.8652 - bag_output_loss: 0.7053 - footwear_output_loss: 0.6106 - pose_output_loss: 0.2730 - emotion_output_loss: 0.8000 - gender_output_acc: 0.9231 - image_quality_output_acc: 0.6543 - age_output_acc: 0.4523 - weight_output_acc: 0.6569 - bag_output_acc: 0.6997 - footwear_output_acc: 0.7292 - pose_output_acc: 0.8918 - emotion_output_acc: 0.7122Learning rate:  5e-07
# 360/360 [==============================] - 169s 470ms/step - loss: 5.4225 - gender_output_loss: 0.1873 - image_quality_output_loss: 0.7521 - age_output_loss: 1.2294 - weight_output_loss: 0.8654 - bag_output_loss: 0.7050 - footwear_output_loss: 0.6107 - pose_output_loss: 0.2725 - emotion_output_loss: 0.8000 - gender_output_acc: 0.9232 - image_quality_output_acc: 0.6545 - age_output_acc: 0.4525 - weight_output_acc: 0.6569 - bag_output_acc: 0.7000 - footwear_output_acc: 0.7293 - pose_output_acc: 0.8921 - emotion_output_acc: 0.7124 - val_loss: 6.8352 - val_gender_output_loss: 0.4467 - val_image_quality_output_loss: 0.9403 - val_age_output_loss: 1.3400 - val_weight_output_loss: 0.9236 - val_bag_output_loss: 0.8473 - val_footwear_output_loss: 0.8447 - val_pose_output_loss: 0.6050 - val_emotion_output_loss: 0.8876 - val_gender_output_acc: 0.8291 - val_image_quality_output_acc: 0.5519 - val_age_output_acc: 0.4103 - val_weight_output_acc: 0.6411 - val_bag_output_acc: 0.6250 - val_footwear_output_acc: 0.6351 - val_pose_output_acc: 0.7812 - val_emotion_output_acc: 0.7036
# Epoch 53/100
# Epoch 54/100
# Learning rate:  5e-07
#
# Epoch 00054: LearningRateScheduler setting learning rate to 5e-07.
# 359/360 [============================>.] - ETA: 0s - loss: 5.3900 - gender_output_loss: 0.1719 - image_quality_output_loss: 0.7572 - age_output_loss: 1.2297 - weight_output_loss: 0.8644 - bag_output_loss: 0.7036 - footwear_output_loss: 0.6039 - pose_output_loss: 0.2633 - emotion_output_loss: 0.7959 - gender_output_acc: 0.9298 - image_quality_output_acc: 0.6499 - age_output_acc: 0.4594 - weight_output_acc: 0.6571 - bag_output_acc: 0.7020 - footwear_output_acc: 0.7314 - pose_output_acc: 0.8987 - emotion_output_acc: 0.7135Learning rate:  5e-07
# Epoch 00059: LearningRateScheduler setting learning rate to 5e-07.
# 360/360 [==============================] - 170s 471ms/step - loss: 5.4340 - gender_output_loss: 0.1813 - image_quality_output_loss: 0.7594 - age_output_loss: 1.2322 - weight_output_loss: 0.8703 - bag_output_loss: 0.6999 - footwear_output_loss: 0.6106 - pose_output_loss: 0.2802 - emotion_output_loss: 0.8001 - gender_output_acc: 0.9274 - image_quality_output_acc: 0.6482 - age_output_acc: 0.4501 - weight_output_acc: 0.6573 - bag_output_acc: 0.7041 - footwear_output_acc: 0.7307 - pose_output_acc: 0.8932 - emotion_output_acc: 0.7127 - val_loss: 6.8372 - val_gender_output_loss: 0.4465 - val_image_quality_output_loss: 0.9401 - val_age_output_loss: 1.3402 - val_weight_output_loss: 0.9236 - val_bag_output_loss: 0.8473 - val_footwear_output_loss: 0.8459 - val_pose_output_loss: 0.6058 - val_emotion_output_loss: 0.8878 - val_gender_output_acc: 0.8296 - val_image_quality_output_acc: 0.5519 - val_age_output_acc: 0.4103 - val_weight_output_acc: 0.6411 - val_bag_output_acc: 0.6260 - val_footwear_output_acc: 0.6366 - val_pose_output_acc: 0.7838 - val_emotion_output_acc: 0.7041
# Epoch 60/100
# Learning rate:  5e-07
#
# Epoch 00060: LearningRateScheduler setting learning rate to 5e-07.
# 360/360 [==============================] - 169s 471ms/step - loss: 5.4290 - gender_output_loss: 0.1819 - image_quality_output_loss: 0.7553 - age_output_loss: 1.2335 - weight_output_loss: 0.8680 - bag_output_loss: 0.7016 - footwear_output_loss: 0.6115 - pose_output_loss: 0.2743 - emotion_output_loss: 0.8029 - gender_output_acc: 0.9265 - image_quality_output_acc: 0.6545 - age_output_acc: 0.4520 - weight_output_acc: 0.6564 - bag_output_acc: 0.7018 - footwear_output_acc: 0.7343 - pose_output_acc: 0.8943 - emotion_output_acc: 0.7116 - val_loss: 6.8382 - val_gender_output_loss: 0.4462 - val_image_quality_output_loss: 0.9408 - val_age_output_loss: 1.3403 - val_weight_output_loss: 0.9234 - val_bag_output_loss: 0.8476 - val_footwear_output_loss: 0.8458 - val_pose_output_loss: 0.6066 - val_emotion_output_loss: 0.8875 - val_gender_output_acc: 0.8291 - val_image_quality_output_acc: 0.5524 - val_age_output_acc: 0.4108 - val_weight_output_acc: 0.6411 - val_bag_output_acc: 0.6260 - val_footwear_output_acc: 0.6341 - val_pose_output_acc: 0.7818 - val_emotion_output_acc: 0.7036
# Epoch 61/100
# Learning rate:  5e-07
#
# Epoch 00061: LearningRateScheduler setting learning rate to 5e-07.
# 359/360 [============================>.] - ETA: 0s - loss: 5.4294 - gender_output_loss: 0.1812 - image_quality_output_loss: 0.7492 - age_output_loss: 1.2323 - weight_output_loss: 0.8702 - bag_output_loss: 0.7037 - footwear_output_loss: 0.6132 - pose_output_loss: 0.2766 - emotion_output_loss: 0.8030 - gender_output_acc: 0.9257 - image_quality_output_acc: 0.6543 - age_output_acc: 0.4518 - weight_output_acc: 0.6571 - bag_output_acc: 0.7044 - footwear_output_acc: 0.7313 - pose_output_acc: 0.8922 - emotion_output_acc: 0.7120Learning rate:  5e-07
#
# Epoch 00061: LearningRateScheduler setting learning rate to 5e-07.
# 360/360 [==============================] - 169s 470ms/step - loss: 5.4303 - gender_output_loss: 0.1815 - image_quality_output_loss: 0.7494 - age_output_loss: 1.2328 - weight_output_loss: 0.8700 - bag_output_loss: 0.7036 - footwear_output_loss: 0.6133 - pose_output_loss: 0.2769 - emotion_output_loss: 0.8027 - gender_output_acc: 0.9255 - image_quality_output_acc: 0.6544 - age_output_acc: 0.4516 - weight_output_acc: 0.6573 - bag_output_acc: 0.7043 - footwear_output_acc: 0.7312 - pose_output_acc: 0.8920 - emotion_output_acc: 0.7120 - val_loss: 6.8395 - val_gender_output_loss: 0.4464 - val_image_quality_output_loss: 0.9411 - val_age_output_loss: 1.3402 - val_weight_output_loss: 0.9236 - val_bag_output_loss: 0.8477 - val_footwear_output_loss: 0.8463 - val_pose_output_loss: 0.6070 - val_emotion_output_loss: 0.8874 - val_gender_output_acc: 0.8286 - val_image_quality_output_acc: 0.5524 - val_age_output_acc: 0.4083 - val_weight_output_acc: 0.6406 - val_bag_output_acc: 0.6270 - val_footwear_output_acc: 0.6351 - val_pose_output_acc: 0.7823 - val_emotion_output_acc: 0.7036
# Epoch 62/100
# Learning rate:  5e-07
#
# Epoch 00062: LearningRateScheduler setting learning rate to 5e-07.
# 360/360 [==============================] - 169s 469ms/step - loss: 5.4228 - gender_output_loss: 0.1856 - image_quality_output_loss: 0.7568 - age_output_loss: 1.2316 - weight_output_loss: 0.8661 - bag_output_loss: 0.7019 - footwear_output_loss: 0.6047 - pose_output_loss: 0.2772 - emotion_output_loss: 0.7988 - gender_output_acc: 0.9244 - image_quality_output_acc: 0.6519 - age_output_acc: 0.4556 - weight_output_acc: 0.6545 - bag_output_acc: 0.7028 - footwear_output_acc: 0.7332 - pose_output_acc: 0.8931 - emotion_output_acc: 0.7126 - val_loss: 6.8394 - val_gender_output_loss: 0.4463 - val_image_quality_output_loss: 0.9409 - val_age_output_loss: 1.3403 - val_weight_output_loss: 0.9236 - val_bag_output_loss: 0.8479 - val_footwear_output_loss: 0.8464 - val_pose_output_loss: 0.6066 - val_emotion_output_loss: 0.8874 - val_gender_output_acc: 0.8286 - val_image_quality_output_acc: 0.5534 - val_age_output_acc: 0.4103 - val_weight_output_acc: 0.6421 - val_bag_output_acc: 0.6270 - val_footwear_output_acc: 0.6356 - val_pose_output_acc: 0.7833 - val_emotion_output_acc: 0.7036
# Epoch 63/100
# Learning rate:  5e-07
#
# Epoch 00063: LearningRateScheduler setting learning rate to 5e-07.
# 359/360 [============================>.] - ETA: 0s - loss: 5.3996 - gender_output_loss: 0.1791 - image_quality_output_loss: 0.7542 - age_output_loss: 1.2308 - weight_output_loss: 0.8658 - bag_output_loss: 0.6923 - footwear_output_loss: 0.6062 - pose_output_loss: 0.2705 - emotion_output_loss: 0.8007 - gender_output_acc: 0.9289 - image_quality_output_acc: 0.6551 - age_output_acc: 0.4507 - weight_output_acc: 0.6542 - bag_output_acc: 0.7100 - footwear_output_acc: 0.7322 - pose_output_acc: 0.8962 - emotion_output_acc: 0.7127Learning rate:  5e-07
#
# Epoch 00063: LearningRateScheduler setting learning rate to 5e-07.
# 360/360 [==============================] - 169s 469ms/step - loss: 5.3993 - gender_output_loss: 0.1795 - image_quality_output_loss: 0.7538 - age_output_loss: 1.2308 - weight_output_loss: 0.8655 - bag_output_loss: 0.6929 - footwear_output_loss: 0.6067 - pose_output_loss: 0.2702 - emotion_output_loss: 0.7999 - gender_output_acc: 0.9286 - image_quality_output_acc: 0.6553 - age_output_acc: 0.4506 - weight_output_acc: 0.6546 - bag_output_acc: 0.7095 - footwear_output_acc: 0.7319 - pose_output_acc: 0.8963 - emotion_output_acc: 0.7131 - val_loss: 6.8369 - val_gender_output_loss: 0.4460 - val_image_quality_output_loss: 0.9407 - val_age_output_loss: 1.3401 - val_weight_output_loss: 0.9232 - val_bag_output_loss: 0.8475 - val_footwear_output_loss: 0.8460 - val_pose_output_loss: 0.6062 - val_emotion_output_loss: 0.8872 - val_gender_output_acc: 0.8281 - val_image_quality_output_acc: 0.5529 - val_age_output_acc: 0.4098 - val_weight_output_acc: 0.6416 - val_bag_output_acc: 0.6250 - val_footwear_output_acc: 0.6356 - val_pose_output_acc: 0.7812 - val_emotion_output_acc: 0.7041
# Epoch 64/100
# Learning rate:  5e-07
#
# Epoch 00064: LearningRateScheduler setting learning rate to 5e-07.
# 232/360 [==================>...........] - ETA: 56s - loss: 5.4035 - gender_output_loss: 0.1708 - image_quality_output_loss: 0.7528 - age_output_loss: 1.2360 - weight_output_loss: 0.8636 - bag_output_loss: 0.6976 - footwear_output_loss: 0.6092 - pose_output_loss: 0.2639 - emotion_output_loss: 0.8095 - gender_output_acc: 0.9298 - image_quality_output_acc: 0.6569 - age_output_acc: 0.4555 - weight_output_acc: 0.6525 - bag_output_acc: 0.7111 - footwear_output_acc: 0.7314 - pose_output_acc: 0.9003 - emotion_output_acc: 0.7082Buffered data was truncated after reaching the output size limit.

# %%
results = model.evaluate_generator(valid_gen, verbose =1)
# Out:
# 31/31 [==============================] - 15s 485ms/step

# %%
dict(zip(model.metrics_names, results))
# Out:
# {'age_output_acc': 0.40725806451612906,
#  'age_output_loss': 1.340250419032189,
#  'bag_output_acc': 0.6244959677419355,
#  'bag_output_loss': 0.8483628553728904,
#  'emotion_output_acc': 0.704133064516129,
#  'emotion_output_loss': 0.8876420874749461,
#  'footwear_output_acc': 0.6345766129032258,
#  'footwear_output_loss': 0.8468348768449598,
#  'gender_output_acc': 0.8266129032258065,
#  'gender_output_loss': 0.44836553354417125,
#  'image_quality_output_acc': 0.5498991935483871,
#  'image_quality_output_loss': 0.9413033416194301,
#  'loss': 6.844731730799521,
#  'pose_output_acc': 0.7807459677419355,
#  'pose_output_loss': 0.6083296614308511,
#  'weight_output_acc': 0.641633064516129,
#  'weight_output_loss': 0.9236429064504562}

# %%
from matplotlib import pyplot as plt

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
